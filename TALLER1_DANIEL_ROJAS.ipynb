# %%
#1- Sin utilizar el comando abs, escribir un programa que calcule e imprima el valor absoluto de cualquier número (sea entero o decimal).
print('VALOR ABSOLUTO DE UN NÚMERO REAL')
ent=float(input('Digite el número (Entero o con parte decimal)'))
if ent>=0:
    print('El valor absoluto del número digitado es ',ent)
else: 
    print('El valor absoluto del número digitado es ',-1*ent)

# %%
#2- Leer dos números enteros y determinar si la magnitud de la diferencia entre los dos es un número primo.
Num1 = int(input ("ingrese un número entero: "))
Num2 = int(input ("ingrese un número entero: "))
Dif = abs(Num1 - Num2)
Check = 0
for i in range (2,Dif):
    if (Dif % i) == 0:
        Check = 1
        break
if Check == 0:
    print(f"la diferencia es {Dif} y SI es un numero primo")
elif Check == 1:
    print(f"la diferencia es {Dif} y NO es un numero primo")

# %%
#3- Iterar a través de los primeros cien enteros positivos, buscando los múltiplos de 3 e imprimiendo y almacenándolos en una lista hasta encontrar los primeros 15 de ellos. Una vez encontrados, continuar iterando en busca de los múltiplos de 4 y almacenarlos en otra lista.
listamult3=[] 
listamult4=[] 

for x in range(101):
    y=x/3
    if y==int(x/3):          
        listamult3.append(x) 

listamult3=listamult3[:15] 
                            

for x in range(listamult3[14],101): 
    z=x/4
    if z==int(x/4):         
        listamult4.append(x) 
        
print('Los primeros 15 multiplos de 3 en el rango estudiado son', listamult3)
print('Los multiplos de 4 siguientes son', listamult4)

# %%
#4- Hacer un programa que lea las coordenadas (x1,y1,r1) y (x2,y2,r2) que corresponden al centro y al radio de dos círculos. Lea un punto de coordenadas (a,b). Determinar si (a,b) está contenido: a) dentro del círculo 1; b) dentro del círculo 2; c) dentro de ambos círculos; d) fuera de ambos círculos. Recordemos que el círculo es el lugar geométrico de los puntos del plano cuya distancia a otro punto fijo, llamado centro, es menor o igual que una cantidad constante, llamada radio.
import numpy as np
x1 = int(input("ingrese la cordenada en x del circulo 1: "))
y1 = int(input("ingrese la cordenada en y del circulo 1: "))
r1 = int(input("ingrese el radio del circulo 1: "))
x2 = int(input("ingrese la cordenada en x del circulo 2: "))
y2 = int(input("ingrese la cordenada en y del circulo 2: "))
r2 = int(input("ingrese el radio del circulo 2: "))
A = int(input("ingrese la cordenada en x del punto: "))
B = int(input("ingrese la cordenada en y del punto: "))
D1 = np.sqrt((x1-A)**2 + (y1-B)**2)
D2 = np.sqrt((x2-A)**2 + (y2-B)**2)
if D1 < r1 and D2 < r2:
    print("el punto esta dentro de los 2 circulos")
elif D1 < r1:
    print("el punto esta dentro del circulo 1")
elif D2 < r2:
    print("el punto esta dentro del circulo 2")
else:
    print("el punto no esta dentro de ninguno de los circulos")

# %% [markdown]
# ##

# %%
#5- Escribir un programa que reciba una cadena de texto y reporte:a) cuántas letras vocales en mayúscula se entraron;b) cuántas letras con tilde se entraron (minúsculas y mayúsculas);c) cuántos dígitos se entraron,d) cuántos espacios se entraron;e) cuántas palabras reservadas se entraron. Utilizar para ello los métodos de cadenas especializados como .isupper(), .isdigit(), etc. y la palabra reservada in.
cadena = input('Digite una cadena de texto: ')  

vocales = 'AEIOUÜ'
tildes = 'áéíóúÁÉÍÓÚ'  

numvocalesmayu = 0                             
numtildes = 0                                  
numdigitos = 0
numespacios = 0                                
numreservadas = 0                              

for i in cadena:
    if i in vocales:
        numvocalesmayu = numvocalesmayu + 1
        
    elif i in tildes:
        numtildes = numtildes + 1
        
    elif i.isdigit():
        numdigitos = numdigitos + 1
        
    elif i == ' ':
        numespacios = numespacios + 1       

texto_list = cadena.split(' ')

for i in range(len(texto_list)):
    if texto_list[i] in keyword.kwlist:        
        numreservadas = numreservadas + 1
    
print(f'En la cadena de texto ingresada hay: ')
print(f'{numvocalesmayu} vocales en mayúscula')
print(f'{numtildes} letras que llevan tilde')
print(f'{numdigitos} dígitos')
print(f'{numespacios} espacios')
print(f'{numreservadas} palabras reservadas')

# %%
#6- Leer una cadena de texto y organizar alfabéticamente cada una de las letras que la componen, repitiendo cada una tantas veces como se encuentra. Por ejemplo, la cadena ‘tarea importante’ será ‘aaaeeimnoprrttt’. (Note que no se incluyen los espacios).
cadenatext=list(input('Ingrese una cadena de texto= '))
cadenatext.sort()
string= ''.join(cadenatext)
x= string.strip()
print(x)

# %%
#7- Leer una lista de números ya ordenados de forma ascendente y verificar que dicha lista está ordenada. Luego, leer un número e insertarlo en la lista en la posición que le corresponde a dicho número.
Lista = [2,2,3,3,5,5,5,5]
salir = False
for pos,i in enumerate(Lista):
    if pos <= Lista[-1]:
        if i > Lista[pos+1]:
            print("la lista no esta ordenada, ordenela para continuar")
            salir = True
            break 
if salir is False:
    num = int(input("ingrese un numero para ingresar a la lista: "))
    for posi,k in enumerate(Lista):
        if num < k:
            Lista.insert(posi,num)
            break
        if k == Lista[-1]:
            Lista.append(num)
            break
    print(Lista)

# %%
#8- Leer una lista de números enteros y determinar cual es el segundo elemento mayor de dicha lista. No utilizar ningún tipo de algoritmo de ordenamiento para realizar este ejercicio. Por ejemplo, en la lista [11, 22, 3, 4, 22], el segundo número mayor sería el 11; de otro lado, en la lista [1, 1, 1, 1, 1] no existe un segundo elemento mayor.
A = [4,3,6,54,23,87,2,1,3,87,87]

Mayr = max(A)
B = A.count(Mayr)
print(f"El numero mayor es {Mayr}")
for j in range(0,B):
    A.remove(Mayr)
May = max(A)
print(f"El segundo numero mayor es {May}")

# %%
#9- Escribir un programa que calcule términos de la sucesión Un+1 = 3 Un + 1 si Un es impar y U n+1 = Un / 2 si Un es par. El programa tiene que pedir el término U0 y el número de términos a calcular.
print("calculo de términos de la sucesión U(n+1) = 3*Un + 1 si Un es impar y U(n+1) = U(n)/2 si Un es par.")
u0 = int(input("Dame el valor de u0: "))
term = int(input("Cuantos terminos desea: "))
Serie= [u0]
for t in range(term-1):
    if (Serie[t] % 2) != 0:
        Serie.append(int((Serie[t]*3)+1))
    else:
        Serie.append(int(Serie[t]/2))
print(Serie)

# %%
#10- Leer una matriz e imprimir el vector que aparece cuando la matriz se desenreda en forma de espiral que gira en el sentido horario a partir de la esquina inferior derecha.
import numpy as np
Mat = np.random.randint(1,100,(4,5))
print(f"{Mat}\n")
Tot1 = Mat[3, :]
Tot1 = Tot1[::-1]
Mat = np.delete(Mat, 3, axis=0)
Tot2 = Mat[:, 0]
Tot2 = Tot2[::-1]
Mat = np.delete(Mat, 0, axis=1)
Tot3 = Mat[0, :]
Mat = np.delete(Mat, 0, axis=0)
Tot4 = Mat[:, 3]
Mat = np.delete(Mat, 3, axis=1)
Tot5 = Mat[1, :]
Tot5 = Tot5[::-1]
Tot6 = Mat[0, :]
Tot = np.append(Tot1,Tot2) 
Tot = np.append(Tot,Tot3)
Tot = np.append(Tot,Tot4)
Tot = np.append(Tot,Tot5)
Tot = np.append(Tot,Tot6) 
print(Tot)

# %%
#11- Diseñar una función de tres parámetros que pida la altura y anchura de un rectángulo, y el carácter a utilizar para dibujarlo.
def dib():

    base= abs(int(input('Ingrese la base del rectangulo= ')))
    altura= abs(int(input('Ingrese la altura del rectagulo= ')))
    parámetro = input('Ingrese el parámetro: ')  
    while altura>0: 
            r=parámetro 
            print(r*base)
            altura=altura-1 
dib()

# %%
#12- Diseñar una función que pida la anchura de un triángulo y lo dibuje con caracteres producto (*).
def fun_triángulo_1(anchura):        #Función triángulo creciente
    for i in range(1, anchura + 1):
        for j in range(i):
            print("* ", end="")
        print()

def fun_triángulo_2(anchura):        #Función triángulo decreciente
    for i in range(1, anchura):
        for j in range(anchura - i):
            print("* ", end="")
        print()

while True:
    try:
        anchura = int(input("Digite la anchura del triángulo: "))
        if anchura >= 0:
            break
        else:
            print("Debe ingresar valores positivos. Intentelo nuevamente.")
    except ValueError:
        print("Debe ingresar valores enteros. Intentelo nuevamente.")

fun_triángulo_1(anchura)
fun_triángulo_2(anchura)

# %%
#13- Diseñar una función que pida dos años y escriba cuántos años bisiestos hay entre esas dos fechas (incluidos los dos años).
def es_bisiesto(t):
    return t % 400 == 0 or (t % 100 != 0 and t % 4 == 0)

print("Contador de años bisiestos")
inicio = int(input("Escriba un año: "))
print("Escriba otro año posterior a", str(inicio) + ": ", end="")
final = int(input())
while final < inicio:
    print(final, "no es mayor que", str(inicio) + ". Inténtelo de nuevo: ",
          end="")
    final = int(input())

contador = 0
for i in range(inicio, final + 1):
    if es_bisiesto(i):
        contador += 1

print("De", inicio, "a", final, "hay", final - inicio + 1, "año(s),",
      contador, "de ellos bisiesto(s).")

# %%
#14- Diseñar una función que proponga sumas de números positivos (dos números entre 1 y 100) al usuario y compruebe la respuesta. El programa continuará hasta que se acierten cinco sumas. (Tip: para generar los números enteros aleatorios, existe la función random.randint(a,b) de la librería random).
from random import randint

def fun_sumas(x):

    contador = 0
    
    while contador < 5:
        m = randint(0,100)
        n = randint(0,100)
        suma = m + n
        print(f"{m} + {n} =")
        while True:
            try:
                x = int(input("Digite su respuesta: "))
                if x >= 0:
                    break
                else:
                    print("""Su respuesta debe corresponder a un valor positivo. Intentelo de nuevo.""")
            except ValueError:
                print("""Su respuesta debe corresponder a un valor entero. Intentelo nuevamente.""")
        if x == suma:
            contador += 1        

    if contador == 5:  
        print("Haz acertado 5 sumas.")
   
fun_sumas(x)

# %%
#15-Diseñar una función que permita jugar a una versión simplificada del juego Master Mind. El juego consistirá en adivinar la cadena de números distintos. La función debe pedir la longitud de la cadena (de 2 a 9 cifras) y generar aleatoriamente un número con esta cantidad de cifras; después el programa debe ir pidiendo que intente adivinar la cadena de números. En cada intento, el programa informará de cuántos números han sido acertados (el programa considerará que se ha acertado un número si coincide el valor y la posición).
import random as rn 
longitud = int(input('diga la longitud de la cadena: '))
def fun():
    contador_intentos=0
    numero1 =''
    if longitud >= 2 and longitud <= 9:
        for i in range(longitud):
            a = rn.randint(0,9)
            num = str(a)
            numero1 = numero1 + num
        usuario = input('intente adivinar la cadena: ')  
        contador_intentos += 1
        len_usuario = len(usuario)
        
        while len_usuario != longitud:
            usuario = input('la longitud de la cadena ingresada es diferente a la inicial. intente adivinar la cadena: ')
            len_usuario = len(usuario)
        aciertos = 0
        while aciertos < longitud: 
            aciertos = 0
            for j in range(longitud):
                if numero1[j] == usuario [j]:
                    aciertos = aciertos + 1
            if aciertos == longitud: 
                print(f'con {usuario} ha adivinado {aciertos} valores.')
                print('numero de intentos: ',contador_intentos)
                break
            else: 
                usuario = input(f'con {usuario} ha adivinado {aciertos} valores. intente adivinar la cadena: ')
                contador_intentos += 1
                len_usuario = len(usuario)
                while len_usuario != longitud: 
                    usuario = input('la longitud de la cadena ingresada es diferente a la inicial. intente adivinar la cadena: ')
                    len_usuario = len(usuario)
        else: 
            print('la longitud de la cadena ingresada no se encuentra dentro del parametro del ejercicio.')
fun()
